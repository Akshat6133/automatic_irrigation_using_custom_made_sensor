# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_excel("idp.xlsx")

# %%
data
# Out:
#                            Sensor  humidity sensor  2kHz(pF)  20kHz(pF)  \
# 0                     thin type 1              0.0     18.26      17.60
# 1                     thin type 2              0.0     17.62      17.17
# 2                     thin type 3              0.0     19.43      18.10
# 3                     thin type 4              0.0       NaN        NaN
# 4                     thin type 5              0.0       NaN        NaN
# 5                     thin type 6              0.0       NaN        NaN
# 6                             NaN              0.0       NaN        NaN
# 7                      mid type 1              0.0     26.11      24.77
# 8                      mid type 2              0.0     27.50      25.50
# 9                      mid type 3              0.0     31.60      28.25
# 10                     mid type 4              0.0       NaN        NaN
# 11                     mid type 5              0.0       NaN        NaN
# ...
